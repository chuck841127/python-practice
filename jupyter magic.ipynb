# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %%
randn(10)
# Out:
# array([-0.48682256,  1.06922547,  0.96132074, -0.51700265, -1.81957649,
#        -0.29667005,  0.90363763,  2.14656647, -0.3323143 ,  0.05065743])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])
