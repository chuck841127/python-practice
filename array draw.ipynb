# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.58619016, 0.85028072, 0.4863812 , 0.23536158, 0.93704779,
#        0.10021837, 0.3798088 , 0.9501391 , 0.91252396, 0.71292248,
#        0.68046462, 0.69773321, 0.15593201, 0.63734941, 0.33691722,
#        0.9829794 , 0.45982414, 0.22838272, 0.92570227, 0.83968586,
#        0.81361948, 0.3119568 , 0.52530721, 0.04394441, 0.3618749 ,
#        0.99966367, 0.44539173, 0.34254289, 0.30192857, 0.41175158,
#        0.82430319, 0.68874993, 0.06041246, 0.78418004, 0.65729208,
#        0.93491934, 0.65829409, 0.22978916, 0.66371321, 0.61504514,
#        0.60061171, 0.0577053 , 0.2852586 , 0.72270471, 0.53705723,
#        0.69538082, 0.45312982, 0.74016143, 0.36642952, 0.71017734])

# %%
plt.plot(y)

# %%
x = np.random.rand(50)

# %%
x
# Out:
# array([0.82846496, 0.12032045, 0.1628936 , 0.44905256, 0.6568235 ,
#        0.65842788, 0.81648732, 0.1069174 , 0.80920795, 0.15606958,
#        0.24230353, 0.83948228, 0.49501348, 0.61733492, 0.64344022,
#        0.37854309, 0.03863292, 0.41691374, 0.94450318, 0.71079958,
#        0.56082022, 0.29059008, 0.48467114, 0.17541026, 0.42899037,
#        0.09511541, 0.98551933, 0.89216807, 0.7275426 , 0.23842312,
#        0.14436283, 0.96252725, 0.15292899, 0.71708957, 0.67817259,
#        0.51311393, 0.51219839, 0.90516925, 0.85267081, 0.92823611,
#        0.00486866, 0.90348043, 0.29915224, 0.43719296, 0.68066611,
#        0.35828268, 0.0266588 , 0.03644095, 0.19883002, 0.90289096])

# %%
plt.plot(x,y)

# %%
x = np.linspace(0,10,100) #np,linespace(起始值,結束值,多少點)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x)+x)

# %%
plt.plot(x,np.sin(x)+x)
plt.plot(x,np.cos(x)+x)
