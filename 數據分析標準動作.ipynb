# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot((3,-4,1,5,-2,7,3,1,2))

# %%
plt.plot(np.random.randn(100))

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
